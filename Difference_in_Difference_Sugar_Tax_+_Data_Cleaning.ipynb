# %% [markdown]
# # The Effect of the Sweetened Beverage Tax on Non-Alcoholic Beverages in Newfoundland
#
# *The objective of this project is solely to demonstrate how a difference-in-difference model and event study figures can be used to study tax incidence*
#
#
# ## Background
#
# On September 1, 2022, [the Government of ***Newfoundland and Labrador*** (NL) introduced a tax on sugary drinks to encourage healthier beverage choices](https://healthydebate.ca/2023/03/topic/newfoundland-labrador-sugar-tax/#:~:text=Newfoundland%20and%20Labrador%20became%20the,1%2C%202022.). The provincial Government [has justified](https://www.gov.nl.ca/fin/files/21702_sugar_factsheet.pdf) the initiative by stating that it aligns with recommendations from key health organizations like the World Health Organization and Canada's Food Guide. The Province intends to use th revenue from the tax to support initiatives such as the Physical Activity Tax Credit and school meal programs, promoting better health outcomes for residents.
#
# **The sugar tax of 20 cents per litre** is collected in addition to the provincial sales tax. The sugar tax is therefore levied on the drink's volume and not on the amount of sugar contained in the beverage. [The tax on sugary beverages includes ready-to-drink options such as](https://www.gov.nl.ca/fin/files/21702_sugar_factsheet.pdf):
#
# - Soft drinks,
# - Fruit-flavored drinks,
# - Sports and energy drinks
# - Dispensed beverages like soda fountain drinks, slush drinks, and fruit juices.
#
# However, certain beverages are exempt from the tax:
#
# - 100% natural fruit or vegetable juices
# - Sugar-free sodas
# - Chocolate milk
# - Alcoholic beverages
# - Syrups, purées, and powders used primarily for cooking or food preparation.
# - Beverages prepared at the time of purchase in food and beverage establishments, such as sweetened coffee or tea.
#
# [When it comes to concentrated drink mixtures](https://www.gov.nl.ca/fin/sugar-sweetened-beverage-tax/), including frozen concentrated sweetened fruit punches, flavoured drink crystals, powders, and syrups with added sugar, the different rate can be applied. For beverages with clear preparation instructions, the tax applies at a rate of 20 cents per litre. However, for those lacking clear instructions, the tax is higher:
#
# - 0.80 CAD per litre for frozen concentrated juices,
# - 2.00 CAD per kilogram for flavoured powders,
# - 1.20 CAD per litre for syrups.
#
# This tax structure is supposed to incentivize manufacturers to provide clear preparation guidelines, thus facilitating informed consumer choices and promoting public health objectives.
#
#
# ## Objective
#
# My objective in this project is to analyze and measure the effect of the ***Sugar-Sweetened Beverage tax*** on non-alcoholic beverages implemented in the Province of ***Newfoundland and Labrador***, Canada.
#
# I will use the framework of a ***Difference-in-Difference*** (DID) econometric model to achieve that objective. A dynamic and static specification of the model will be considered. The dynamic specification will be used to verify the presence of any pre-trend that violates the assumptions of the model and the long-term effects of the tax. The static specification will be used to verify the magnitude of the effect of the tax, by controlling for covariates that could bias the estimation of the variable of interest.
#
# ## Methodology
#
# The [difference-in-difference](https://www.sciencedirect.com/science/article/abs/pii/S1573446399030047) (DID) method is commonly used to determine if a particular event caused a change in a specific outcome and to quantify the size of this change. This method is used often for its simplicity and adaptability, making it easy to grasp and apply in various situations (Angrist et al, 1999). It also accounts for changes in the outcome that are not directly caused by the event itself. However, there are limitations to consider. DID requires two sets of observations, one affected by the event and one not, in other words, a treatment and a control group, respectively. Certain assumptions must be met, including the independence of the event from the outcome variable and the stability of characteristics in both sets of observations. The most crucial assumption is that both sets of data follow a similar trend over time, also referred to as the **parallel trends assumption**. Despite these limitations, the DID method was selected for its ability to meet the research objectives effectively. For this project, I use the [non-alcoholic beverages](https://doi.org/10.25318/1810000401-eng) subset of the Canadian Consumer Price Index (CPI) as the dependent variable.
#
# To formalize this approach I denote the ten Canadian provinces as $i \in \{1, 2, ..., 10\}$. The time variable is denoted as $t \in \{1, 2, ..., 27 \}$, these integers represent the monthly observations from September 2021 to November 2023. The dependent variable is represented by $Y_{it}$. The binary treatment variable is written as $D_{it} \in \{ 0, 1 \}$, where $D_{it} = 0$ means that province $i$ was not treated at time $t$ and $D_{it}$ means that province $i$ was treated at time $t$. The treatment period is denoted as $E_{i} = min\{t: D_{it} = 1\}$, this period is also referred to as "event time." I also define the variable $K_{it} = E_i - t$ as the ``relative time,'' which expresses time periods as a number relative to the event time. After considering this information, I can write the ***dynamic specification*** as Equation 1:
#
# $$Y_{it} = \alpha + \beta_i + \delta_t + \sum_{k = -A}^Z \tau_k D_{it} + ϵ_{it} $$
#
# Where $A \geq 0$ and $Z \geq 0$ represent the leads and lags of the treatment, respectively. Province fixed effects are denoted by $\beta_i$ and time fixed effects by $\delta_t$. The error term is shown as $\epsilon_{it}$ and errors are clustered at the province level. The constant term is represented by $\alpha$.
#
# In the dynamic specification, the outcome of interest is $\tau_k$, which represents the time-varying effects of the sugar tax. To avoid issues of multicollinearity, I normalize the estimation by setting $\tau_{-1} = 0$.
#
# To quantify the effect of the sugar tax on non-alcoholic beverages in NL, I use the static specification of the DID model. This specification can be written as Equation 2:
#
# $$Y_{it} = \alpha + \beta_i + \delta_t + \tau D_{it} + X^\prime \gamma + \epsilon_{it}$$
#
# Where a set of variables $X^\prime$ and estimators $\gamma$ are included in the model to control for covariates that could bias the estimation. In this specification, $\tau$ is the coefficient of interest, and it measures the average treatment effect of the sugar tax on non-alcoholic beverages.
#
# ## Results
#
# We can first verify the validity of the parallel trends assumption by analyzing Figure 1. This figure suggests that non-alcoholic beverage prices are parallel between the provinces. Trends observed in one province can be observed in a similar way in other provinces at the same time. We can also see that there is a jump that happens in non-alcoholic beverage prices exactly when the sugar tax is implemented. It is important to note that, as of April 1, 2021, soda beverages no longer qualify for the Provincial Sales Tax (PST) exemption in British Columbia, resulting in the PST being applied to all retail sales of soda beverages at a rate of 7%. Since the period being considered here only includes the period between September 2021 to November 2023, this change should not interfere with estimations here, since the trends between NL and BC are not affected by this change in the BC legislation in the period considered.
#
# **Figure 1**: Non-Alcoholic Beverage Price by Province.
#
# ![Non-Alcoholic Beverage Price by Province](./figures/non_alcohol_bev.png)
#
# Source: Statistics Canada. [Table 18-10-0004-01  Consumer Price Index, monthly, not seasonally adjusted](https://doi.org/10.25318/1810000401-eng)
#
# We can see the results of the dynamic specification graphically by plotting $\tau_k$ from Equation 1. We can see the dynamic treatment effects plotted in Figure 2. We can see that the pre-trends do not present strong evidence of a systematic violation of the parallel trends assumption, as the lead coefficients are mostly not significantly different than zero. On the other hand, we can see that lag coefficients are significantly different than zero. **These results suggest that the implementation of the tax increase the price of non-alcoholic beverages in NL.**
#
# **Figure 2**: The Effect of the Sugar Tax on Non-Alcoholic Beverages - Dynamic Specification.
#
# ![The Effect of the Sugar Tax on Non-Alcoholic Beverages - Dynamic Specification](./figures/diff-in-diff_sugar_tax.png)
#
# Source: Author's Calculations.
#
# Even though these results are promising and suggest that the tax was the reason for the increase in the dependent variable, the dynamic specification of DID does not provide a reliable measure of the magnitude of the sugar tax effect on the dependent variable. For that, I will consider the static model described in Equation 2. I will also need to control for other variables that could also have an effect on non-alcoholic beverage prices since the exclusion of variables that have an effect on the dependent variable and are correlated with the independent could introduce omitted variable bias in the model, which would make my estimates unreliable.
#
# To prevent the issue of endogeneity mentioned in the last paragraph I included control variables. The reasoning behind their inclusion can be found in the Appendix section. These were the variables included in the static models:
#
# - Unemployment;
# - Average Weekly Earnings;
# - Interest Rates;
# - WTI Oil Prices;
# - CAD/USD Exchange Rate;
# - Stringency Index (SI);
# - Economic Support Index (ESI);
# - Geopolitical Risk Index (GPR).
#
# The results obtained from the static model can be seen in Table 1. To verify the sensibility of the coefficient of interest on the dependent variable, Table 1 has various columns that consider different combinations of control variables. As we can see in Table 1, the effect of the implementation of the sugar tax increased the price of non-alcoholic beverages by 5.30 CAD in the extended model. We can also observe that the treatment variable is statistically significant in every variation of the model. **Figure 3 shows the results of the static model results with error bars**. These results suggest that the burden of sugar-sweetened beverage tax is being completely passed on to the final consumer.
#
# **Table 1**: Static Model Results - Effect of the Sugar Tax on Non-Alcoholic Beverages.
#
# ![Static Model Results - Effect of the Sugar Tax on Non-Alcoholic Beverages](./figures/static_model_results_tab.png)
#
# Source: Author's Calculations.
#
#
# **Figure 3**: Effect of the Sugar Tax on Non-Alcoholic Beverages - Error Bars.
#
# ![Effect of the Sugar-Tax on Non-Alcoholic Beverages - Error Bars](./figures/static_model_plot.png)
#
# Source: Author's Calculations.
#
# ## Conclusion
#
# Overall the model I developed in this research suggests that non-alcoholic drinks in Newfoundland and Labrador increased by 5.30 CAD as a result of the implementation of the Sugar-Sweetened Beverage Tax. The extended model, which controls for seven other variables that can also affect the dependent variable, suggests that the tax increased non-alcoholic beverages at a minimum of roughly 3.00 CAD. **These results provide strong evidence that a disproportionately high portion of the tax burden is falling on the final consumer**.
#
# High tax incidence on consumers is often related to factors such as inelastic demand or market power held by the firms. Inelastic demand implies that consumers are less responsive to price changes, which allows firms to raise prices without experiencing a significant decrease in demand. Additionally, if firms hold market power, they can exert control over prices, which enables them to shift a larger share of the tax burden onto consumers. **Several studies, however, show that the creation of a sugar-sweetened beverage tax decreases demand and that sugary drinks have elastic prices** ([1](https://doi.org/10.1016/j.ehb.2020.100869), [2](https://doi.org/10.1371/journal.pone.0277306), [3](https://doi.org/10.1186/1471-2458-13-1072), [4](https://doi.org/10.1177/1091142103253753), [5](https://doi.org/10.1007/978-3-319-33648-0_3), [6](https://doi.org/10.1001/jamanetworkopen.2022.15276) ). There is no consensus on market power being one of the main drivers of beverage inflation, since some reports point to a increase in profit margins in the period, while others point to no evidence of a mark-up increase ([7](https://centreforfuturework.ca/wp-content/uploads/2022/12/Fifteen-SuperProfitable-Industries.pdf), [8](https://www.ourcommons.ca/Content/Committee/441/AGRI/Reports/RP12503602/agrirp10/agrirp10-e.pdf)).
#
# Some explanations can be considered to explain the high-pass-through rate. It can be that the firms are facing higher costs and having difficulties when attempting to provide clear preparation guidelines for their products, thus running into higher tax rates. Another possible reason is that the demand for sugary drinks is relatively more inelastic in Newfoundland and Labrador than in other regions, since [the typical household allocates approximately 2.8 percent of its yearly food and beverage budget to sugar-sweetened beverages](https://www.gov.nl.ca/releases/2021/fin/1019n06/#:~:text=The%20average%20household%20in%20Newfoundland,Canadian%20average%20of%201.4%20percent.). This proportion stands as the highest among Canadian provinces, doubling the national average expenditure of 1.4 percent. This can be a sign that households in the Province have stronger preferences for sugary drinks. That being considered, it is still uncertain why the tax burden is being passed in excess to the final consumer.
#
# Further studies should be done on the demand for non-alcoholic beverages in Newfoundland. If demand for sugary drinks is found to be inelastic, the Province must consider different policies to achieve the objective of incentivizing healthier beverage choices, since the sugar-sweetened beverage tax would have a limited effect on actual consumption. Studies on the costs associated with the provision of clear preparation guidelines for sugary drink products should also be done, as those could disproportionately impact smaller and local producers. Cost-benefit analysis studies should be performed to assess the net social benefit of this policy in the Province of Newfoundland and Labrador, as these would allow us to better understand if these policies are achieving their intended objectives.
#
#
# **Summary of Conclusions**
#
# 1. Non-alcoholic beverage prices increased by roughly 5.30 CAD as a result of the sugar-sweetened beverage tax.
# 2. There is strong evidence that the tax burden is disproportionally falling on the final consumer.
# 3. It is still uncertain why the tax burden is being disproportionally passed to the final consumer.
# 4. Most of the literature states that the demand for sugary beverages is elastic.
# 5. If the sugar tax is ineffective in reducing demand for sugar-sweetened drinks, the impact of the policy on social welfare is uncertain.
# 6. Research considering different control variables should be considered.
#
# **My recommendations are the following**:
#
# 1. Conducting Cost-Benefit Analysis studies on the actual impact of the sugar-sweetened beverage tax on social welfare.
# 2. More studies on the effect of the Newfoundland and Labrador sugar-sweetened beverage tax effect on actual consumption.
# 3. The Government of Newfoundland and Labrador should consider complementary policies to achieve its objective of incentivizing healthier beverage choices.
# 4. Further studies that include different variables, not considered here, on the effect of the sugar-sweetened beverage tax.
# 5. Further studies should also be done about the possible existence of market power being held by the producers, which could lead to higher prices.
#
#
# ***Overall the results I show here should not be taken should not be taken at face value. The objective of this project is to showcase, in a simplified manner, how a difference-in-difference model can be applied to study tax incidence. Further research should be done about the subject.***
#
#
# ## Appendix
#
# Eight different control variables were used in the extended model presented in Equation 2. The variables chosen as controls were: unemployment, average weekly earnings, WTI Oil prices, CAD/USD exchange rate, Stringency Index (SI), Economic Support Index (ESI) and the Geopolitical Risk Index. These control variables serve to mitigate potential confounding factors and account for external influences on beverage prices beyond the treatment effect of the tax. Unemployment and average weekly earnings reflect economic conditions and consumer purchasing power, while interest rates and oil prices capture broader macroeconomic trends that can affect production costs and inflationary pressures. Exchange rates can influence the competitiveness of Canadian products in the global market and the cost of imported goods and services. The SI and ESI were used to control the COVID-19 pandemic, which left lasting impacts on the global economy. The SI measures the strictness of the social distancing and lockdown measures, while the ESI measures the economic support measures adopted by the local government to mitigate the negative effects of the pandemic. The Geopolitical Risk Index is used to control for Geopolitical factors that affected markets worldwide, such as the Russian-Ukrainian invasion in 2022.
#
# **Figure 4**: Monthly Unemployment Rate - Atlantic Provinces
#
# ![Monthly Unemployment Rate - Atlantic Provinces](./figures/unemployment_rate_Atlantic.png)
#
# Source: Statistics Canada. [Table 14-10-0287-03 - Labour force characteristics by province, monthly, seasonally adjusted](https://doi.org/10.25318/1410028701-eng)
#
# **Figure 5**: Monthly Unemployment Rate - Prarie Provinces
#
# ![Monthly Unemployment Rate - Prarie Provinces](./figures/unemployment_rate_Praries.png)
#
# Source: Statistics Canada. [Table 14-10-0287-03 - Labour force characteristics by province, monthly, seasonally adjusted](https://doi.org/10.25318/1410028701-eng)
#
# **Figure 6**: Monthly Unemployment Rate - Ontario, Quebéc and British Columbia
#
# ![Monthly Unemployment Rate - Ontario, Quebéc and British Columbia](./figures/unemployment_rate_ON_QC_BC.png)
#
# Source: Statistics Canada. [Table 14-10-0287-03 - Labour force characteristics by province, monthly, seasonally adjusted](https://doi.org/10.25318/1410028701-eng)
#
# **Figure 7**: Average Weekly Earnings by Province
#
# ![Average Weekly Earnings by Province](./figures/avg_week_earn.png)
#
# Source: Statistics Canada. [Table 14-10-0223-01 - Employment and average weekly earnings (including overtime) for all employees by province and territory, monthly, seasonally adjusted](https://doi.org/10.25318/1410022301-eng)
#
# **Figure 8**: Canadian Interest Rates
#
# ![Canadian Interest Rates](./figures/interest.png)
#
# Source: [Bank of Canada. Canadian interest rates and monetary policy variables](https://www.bankofcanada.ca/rates/interest-rates/canadian-interest-rates/).
#
# **Figure 9**: WTI Oil Prices
#
# ![WTI Oil Prices](./figures/WTI_Oil.png)
#
# Source: [World Bank. Commodity Prices - "Pink Sheet" Table. Monthly Prices.](https://www.worldbank.org/en/research/commodity-markets)
#
# **Figure 10**: CAD/USD Exchange Rate
#
# ![CAD/USD Exchange Rate](./figures/CADUSD.png)
#
# Source: [Yahoo Finance. CAD/USD (CADUSD=X)](https://ca.finance.yahoo.com/quote/CADUSD=X/)
#
# **Figure 11**: Stringency Index (SI) - Atlantic Provinces
#
# ![Stringency Index (SI) - Atlantic Provinces](./figures/SI_Atlantic.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
# **Figure 12**: Stringency Index (SI) - Prarie Provinces
#
# ![Stringency Index (SI) - Prarie Provinces](./figures/SI_Praries.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
# **Figure 13**: Stringency Index (SI) - Ontario, Quebéc and British Columbia
#
# ![Stringency Index (SI) - Ontario, Quebéc and British Columbia](./figures/SI_ON_QC_BC.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
#
# **Figure 14**: Economic Support Index (ESI) - Atlantic Provinces
#
# ![Economic Support Index (ESI) - Atlantic Provinces](./figures/ESI_Atlantic.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
# **Figure 15**: Economic Support Index (ESI) - Prarie Provinces
#
# ![Economic Support Index (ESI) - Prarie Provinces](./figures/ESI_Praries.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
# **Figure 16**: Stringency Index (SI) - Ontario, Quebéc and British Columbia
#
# ![Economic Support Index (ESI) - Ontario, Quebéc and British Columbia](./figures/ESI_ON_QC_BC.png)
#
# Source: Edouard Mathieu, Hannah Ritchie, Lucas Rodés-Guirao, Cameron Appel, Charlie Giattino, Joe Hasell, Bobbie Macdonald, Saloni Dattani, Diana Beltekian, Esteban Ortiz-Ospina and Max Roser (2020) - "Coronavirus Pandemic (COVID-19)". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/coronavirus'.
#
# **Figure 17**: Geopolitical Risk Index (GPR)
#
# ![Geopolitical Risk Index (GPR)](./figures/GPR.png)
#
# Source: [Caldara, Dario and Matteo Iacoviello (2022), “Measuring Geopolitical Risk,” American Economic Review, April, 112(4), pp.1194-1225.](https://www.matteoiacoviello.com/gpr.htm)

# %% [markdown]
# # Code for the Analysis

# %% [markdown]
# ## Cleaning the Data
#
# You can skip this if you have the clean file I create after this.

# %%
# !pip install pystout

# !pip install linearmodels

# !pip install statsmodels

# Importing packages

from pystout import pystout

import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
from scipy import stats

import statsmodels.formula.api as sm
import statsmodels.stats.sandwich_covariance as sw

import statsmodels as statsmodels
import linearmodels as lm
import matplotlib.pyplot as plt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# Importing the main dataset

dataset = pd.read_csv("18100004.csv")

dataset.head()
# Out:
# <ipython-input-23-ebe4564b607f>:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("18100004.csv")
#   REF_DATE     GEO           DGUID Products and product groups       UOM  \
# 0  1914-01  Canada  2016A000011124                   All-items  2002=100
# 1  1914-01  Canada  2016A000011124        All-items (1992=100)  1992=100
# 2  1914-01  Canada  2016A000011124          Goods and services  2002=100
# 3  1914-02  Canada  2016A000011124                   All-items  2002=100
# 4  1914-02  Canada  2016A000011124        All-items (1992=100)  1992=100
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  COORDINATE  VALUE STATUS  \
# 0      17         units          0  v41690973       2.200    6.0    NaN
# 1       7         units          0  v41713403       2.309    7.2    NaN
# 2      17         units          0  v41691221       2.273    6.0    NaN
# ...

# %%
# Filtering only provinces

df = dataset[(dataset['GEO'] == 'Newfoundland and Labrador') | (dataset['GEO'] == 'Prince Edward Island') | (dataset['GEO'] == 'Nova Scotia') | (dataset['GEO'] == 'New Brunswick') | (dataset['GEO'] == 'Quebec') | (dataset['GEO'] == 'Ontario') | (dataset['GEO'] == 'Manitoba') | (dataset['GEO'] == 'Saskatchewan') | (dataset['GEO'] == 'Alberta') | (dataset['GEO'] == 'British Columbia')]

unique_provinces = df['GEO'].drop_duplicates()

print(unique_provinces)
# Out:
# 39784    Newfoundland and Labrador
# 39894         Prince Edward Island
# 40002                  Nova Scotia
# 40112                New Brunswick
# 40222                       Quebec
# 40339                      Ontario
# 40462                     Manitoba
# 40573                 Saskatchewan
# 40690                      Alberta
# 40806             British Columbia
# Name: GEO, dtype: object

# %%
# Filtering unique items

df = df[(df['Products and product groups'] == 'Non-alcoholic beverages')]

unique_items = df['Products and product groups'].drop_duplicates()

print(unique_items)
# Out:
# 39808    Non-alcoholic beverages
# Name: Products and product groups, dtype: object

# %%
# Defining the date column

df['REF_DATE'] = pd.to_datetime(df['REF_DATE'], format='%Y-%m')

# Defining a cutoff date

cutoff_date = '2021-09-01'

# Dropping observations before the cutoff date

df = df[df['REF_DATE'] >= cutoff_date]

# Generate a custom time variable

## This will measure time as a integer

df['t'] = df.groupby('GEO').cumcount() + 1
# Out:
# <ipython-input-26-e1a8ba92a231>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['t'] = df.groupby('GEO').cumcount() + 1

# %%
# Generates a variable with the event date as an integer

event_date = '2022-09-01'

event_scalar = df[(df['REF_DATE'] == event_date)]

event_scalar = event_scalar['t'].drop_duplicates()

event_scalar = int(event_scalar)

event_scalar
# Out:
# 13

# %%
# Generating an event time variable
## This variable contains the time period in which the event happened

df['Ei'] = np.where(df['GEO'] == 'Newfoundland and Labrador', event_scalar, np.nan)

df.head()
# Out:
#           REF_DATE                        GEO        DGUID  \
# 1033729 2021-09-01  Newfoundland and Labrador  2016A000210
# 1033868 2021-09-01       Prince Edward Island  2016A000211
# 1034006 2021-09-01                Nova Scotia  2016A000212
# 1034145 2021-09-01              New Brunswick  2016A000213
# 1034284 2021-09-01                     Quebec  2016A000224
#
#         Products and product groups       UOM  UOM_ID SCALAR_FACTOR  \
# 1033729     Non-alcoholic beverages  2002=100      17         units
# 1033868     Non-alcoholic beverages  2002=100      17         units
# 1034006     Non-alcoholic beverages  2002=100      17         units
# 1034145     Non-alcoholic beverages  2002=100      17         units
# 1034284     Non-alcoholic beverages  2002=100      17         units
#
#          SCALAR_ID     VECTOR  COORDINATE  VALUE STATUS  SYMBOL TERMINATED  \
# 1033729          0  v41691275        3.74  110.2    NaN     NaN        NaN
# ...

# %%
# Getting unique provinces sorted alphabetically
unique_provinces = sorted(df['GEO'].unique())

# Creating a dictionary to map provinces to integers
province_map = {province: idx + 1 for idx, province in enumerate(unique_provinces)}

# Creating a variable with the encoded provinces

df['i'] = df['GEO'].map(province_map)

# Renaming the dependent variable column

df = df.rename(columns={'VALUE': 'Y'})

# Showing the dataset

df
# Out:
#           REF_DATE                        GEO        DGUID  \
# 1033729 2021-09-01  Newfoundland and Labrador  2016A000210
# 1033868 2021-09-01       Prince Edward Island  2016A000211
# 1034006 2021-09-01                Nova Scotia  2016A000212
# 1034145 2021-09-01              New Brunswick  2016A000213
# 1034284 2021-09-01                     Quebec  2016A000224
# ...            ...                        ...          ...
# 1087851 2023-12-01                    Ontario  2016A000235
# 1088002 2023-12-01                   Manitoba  2016A000246
# 1088143 2023-12-01               Saskatchewan  2016A000247
# 1088289 2023-12-01                    Alberta  2016A000248
# 1088434 2023-12-01           British Columbia  2016A000259
#
#         Products and product groups       UOM  UOM_ID SCALAR_FACTOR  \
# 1033729     Non-alcoholic beverages  2002=100      17         units
# 1033868     Non-alcoholic beverages  2002=100      17         units
# ...

# %%
# Dropping non-useful columns

columns_to_keep = ['GEO', 'i', 'REF_DATE', 't', 'Ei', 'Y', 'Products and product groups']

df = df[columns_to_keep]

# Creating a column with a copy of the panel identifiers i. These are usefol for loops

df['i2'] = df['i']

df
# Out:
# <ipython-input-30-917f14735257>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i2'] = df['i']
#                                GEO   i   REF_DATE   t    Ei      Y  \
# 1033729  Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1033868       Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 1034006                Nova Scotia   6 2021-09-01   1   NaN  152.9
# 1034145              New Brunswick   4 2021-09-01   1   NaN  137.8
# 1034284                     Quebec   9 2021-09-01   1   NaN  136.2
# ...                            ...  ..        ...  ..   ...    ...
# 1087851                    Ontario   7 2023-12-01  28   NaN  156.1
# 1088002                   Manitoba   3 2023-12-01  28   NaN  152.0
# ...

# %%
# Creating a treatment variable for the static model

df['D'] = np.where((df['t'] >= df['Ei']) & (df['GEO'] == 'Newfoundland and Labrador'), 1, 0)
# Out:
# <ipython-input-31-0e0b19d2d304>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['D'] = np.where((df['t'] >= df['Ei']) & (df['GEO'] == 'Newfoundland and Labrador'), 1, 0)

# %% [markdown]
# ## Merging the Control Variables to Main Dataset

# %% [markdown]
# ### Merging the Geopolitical Risk Index (GPR) to the Main Dataset

# %%
# Load the dataset with the Geopolitical Risk Index (GPR)

dataset2 = pd.read_excel("data_gpr_export.xls")

# Renaming the date column

dataset2.rename(columns={'month': 'REF_DATE'}, inplace=True)

# Drop irrelevant columns

dataset2 = dataset2[['REF_DATE', 'GPR']]

# Merge dataframes based on the REF_DATE column
df = pd.merge(df, dataset2, on='REF_DATE', how='inner')

# Shows the Dataframe

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 275                    Ontario   7 2023-12-01  28   NaN  156.1
# 276                   Manitoba   3 2023-12-01  28   NaN  152.0
# 277               Saskatchewan  10 2023-12-01  28   NaN  169.5
# 278                    Alberta   1 2023-12-01  28   NaN  173.2
# 279           British Columbia   2 2023-12-01  28   NaN  166.4
#
#     Products and product groups  i2  D         GPR
# 0       Non-alcoholic beverages   5  0   80.696968
# 1       Non-alcoholic beverages   8  0   80.696968
# 2       Non-alcoholic beverages   6  0   80.696968
# ...

# %% [markdown]
# ### Merging the Stringency Index (SI) to the Main Dataset

# %%
# Importing Stringency and Economic Support Index dataset from github

url = "https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/Canada/OxCGRT_CAN_latest.csv"

dataset3 = pd.read_csv(url)

# Filtering the dataset

## List of Canadian provinces
provinces = ['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick', 'Newfoundland and Labrador',
             'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec', 'Saskatchewan']

dataset3.rename(columns={'RegionName': 'GEO', 'Date': 'REF_DATE'}, inplace=True)

# Filter the DataFrame to include only the provinces
dataset3 = dataset3[dataset3['GEO'].isin(provinces)]

# Dropping irrelevant columns

dataset3 = dataset3[['GEO', 'REF_DATE', 'StringencyIndex_Average', 'EconomicSupportIndex']]

# Setting the date variable

dataset3['REF_DATE'] = pd.to_datetime(dataset3['REF_DATE'], format='%Y%m%d')

# Merging to the main dataset

df = pd.merge(df, dataset3, on=['GEO', 'REF_DATE'], how='left')

# Filling NaN observations with 0 for the relevant variables

df['StringencyIndex_Average'].fillna(0, inplace=True)

df['EconomicSupportIndex'].fillna(0, inplace=True)

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 275                    Ontario   7 2023-12-01  28   NaN  156.1
# 276                   Manitoba   3 2023-12-01  28   NaN  152.0
# 277               Saskatchewan  10 2023-12-01  28   NaN  169.5
# 278                    Alberta   1 2023-12-01  28   NaN  173.2
# 279           British Columbia   2 2023-12-01  28   NaN  166.4
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ### Merging the Canadian Interest Rates to the Main Dataset

# %%
# Load the dataset with the Canadian Interest Rates

dataset4 = pd.read_csv("interest_rates.csv", skiprows=11)

# Renaming the date and interest columns

dataset4.rename(columns={'Date': 'REF_DATE', 'V122530': 'interest'}, inplace=True)

# Convert 'REF_DATE' column to datetime format
dataset4['REF_DATE'] = pd.to_datetime(dataset4['REF_DATE'])

# Merge dataframes based on the REF_DATE column
df = pd.merge(df, dataset4, on='REF_DATE', how='inner')

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 275                    Ontario   7 2023-12-01  28   NaN  156.1
# 276                   Manitoba   3 2023-12-01  28   NaN  152.0
# 277               Saskatchewan  10 2023-12-01  28   NaN  169.5
# 278                    Alberta   1 2023-12-01  28   NaN  173.2
# 279           British Columbia   2 2023-12-01  28   NaN  166.4
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ### Merging Average Weekly Earnings to the Main Dataset

# %%
# Importing dataset with average weekly earnings

dataset5 = pd.read_csv("1410022301_databaseLoadingData.csv")

# Setting REF_DATE as the date variable

dataset5['REF_DATE'] = pd.to_datetime(dataset5['REF_DATE'])

# Renaming the value variable to avg_earn

dataset5.rename(columns={'VALUE': 'avg_earn'}, inplace=True)

# Dropping columns that are not relevant

dataset5 = dataset5[['REF_DATE', 'GEO', 'avg_earn']]

# Merging the average weekly earnings dataset to the main dataset

df = pd.merge(df, dataset5, on=['REF_DATE', 'GEO'], how='inner')

# Creating a variable with the log of average earnings

df['log_avg_earn'] = np.log(df['avg_earn'])

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ### Merging the Unemployment Variable to the Main Dataset

# %%
# Importing dataset with average weekly earnings

dataset6 = pd.read_csv('14100017.csv')

# Setting REF_DATE as the date variable

dataset6['REF_DATE'] = pd.to_datetime(dataset6['REF_DATE'])

# Filtering the dataset

dataset6 = dataset6[dataset6['Labour force characteristics'] == 'Unemployment rate']

dataset6 = dataset6[dataset6['Sex'] == 'Both sexes']

dataset6 = dataset6[dataset6['Age group'] == '15 years and over']

dataset6 = dataset6[dataset6['UOM'] == 'Percentage']

# Dropping other variables

dataset6 = dataset6[['REF_DATE', 'GEO', 'VALUE']]

# Renaming the unemployment variable

dataset6.rename(columns={'VALUE': 'unemp'}, inplace=True)

# Merging the average weekly earnings dataset to the main dataset

df = pd.merge(df, dataset6, on=['REF_DATE', 'GEO'], how='inner')

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ### Merging the WTI Oil Variable to the Main Dataset

# %%
# Read the Excel file

dataset7 = pd.read_excel('CMO-Historical-Data-Monthly.xlsx', sheet_name=1, skiprows=4)

# Drop the first 2 rows

dataset7 = dataset7.drop(index=dataset7.index[:2])

# Renames time variable

dataset7.rename(columns={'Unnamed: 0': 'REF_DATE', 'Crude oil, WTI': 'WTI_Oil'}, inplace=True)

# Convert 'REF_DATE' to datetime format

dataset7['REF_DATE'] = pd.to_datetime(dataset7['REF_DATE'], format='%YM%m')

# Drop irrelevant variables

dataset7 = dataset7[['REF_DATE', 'WTI_Oil']]

# Convert WTI Oil to a float variable

# Remove non-numeric values from the column
dataset7['WTI_Oil'] = pd.to_numeric(dataset7['WTI_Oil'], errors='coerce')

#dataset7['WTI_Oil'] = dataset7['WTI_Oil'].astype(float)

# Merging the WTI Oil dataset to the main dataset

df = pd.merge(df, dataset7, on=['REF_DATE'], how='inner')

# Display the DataFrame
df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ### Merging the Exchange Rate to the Main Dataset

# %%
# Import Exchange Rate dataset

dataset8 = pd.read_csv('CADUSD=X.csv')

# Rename Columns

dataset8.rename(columns={'Date': 'REF_DATE', 'Close': 'CADUSD'}, inplace=True)

# Drop irrelevant columns

dataset8 = dataset8[['REF_DATE', 'CADUSD']]

# Convert 'REF_DATE' to datetime format

dataset8['REF_DATE'] = pd.to_datetime(dataset8['REF_DATE'])

# Calculate monthly average

dataset8 = dataset8.resample('M', on='REF_DATE').mean()

# Set the date variable as the first day of each month

dataset8['REF_DATE'] = dataset8.index.strftime('%Y-%m-01')

# Reset index to make 'REF_DATE' a regular column

dataset8.reset_index(drop=True, inplace=True)

# Reorders columns

dataset8 = dataset8[['REF_DATE', 'CADUSD']]

# Sets as time variable again

dataset8['REF_DATE'] = pd.to_datetime(dataset8['REF_DATE'])

# Merging the WTI Oil dataset to the main dataset

df = pd.merge(df, dataset8, on=['REF_DATE'], how='inner')

# Display the DataFrame
df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %% [markdown]
# ## Saving the Main Dataset as a CSV file

# %%
# Saving the DataFrame as a CSV file

df.to_csv('did_sugar.csv', index=False)

# %% [markdown]
# # Runing Diff-in-Diff

# %%
# Loading the main Dataset

df = pd.read_csv('did_sugar.csv')

# Setting datetime variable

df['REF_DATE'] = pd.to_datetime(df['REF_DATE'])

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %%
# Generating relative time variable

df['relative_time'] = (
    df['t'].sub(df['Ei'])
        # missing values for the cohort variable implies no treatment
        .fillna(0)
        # so we don't have decimals in our factor names
        .astype('int')
)

df
# Out:
#                            GEO   i   REF_DATE   t    Ei      Y  \
# 0    Newfoundland and Labrador   5 2021-09-01   1  13.0  110.2
# 1         Prince Edward Island   8 2021-09-01   1   NaN  127.2
# 2                  Nova Scotia   6 2021-09-01   1   NaN  152.9
# 3                New Brunswick   4 2021-09-01   1   NaN  137.8
# 4                       Quebec   9 2021-09-01   1   NaN  136.2
# ..                         ...  ..        ...  ..   ...    ...
# 265                    Ontario   7 2023-11-01  27   NaN  157.0
# 266                   Manitoba   3 2023-11-01  27   NaN  154.1
# 267               Saskatchewan  10 2023-11-01  27   NaN  170.0
# 268                    Alberta   1 2023-11-01  27   NaN  175.9
# 269           British Columbia   2 2023-11-01  27   NaN  166.9
#
#     Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# 0       Non-alcoholic beverages   5  0   80.696968                    50.59
# ...

# %%
# Define a list of 10 different markers

markers = ['o', 's', 'D', '+', '*', 'x', '^', 'v', '>', '<']

# Define a list of 10 different colors
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

marker_index = 0

# set the event date variable as date time

event_date2 = pd.to_datetime(event_date)

# Plot line graph to show paralell trends

plt.figure(figsize=(10, 6))
for key, grp in df.groupby('GEO'):
    plt.plot(grp['REF_DATE'], grp['Y'], label=key, marker=markers[marker_index % len(markers)], color=colors[marker_index % len(colors)])
    marker_index += 1
plt.xlabel('Date')
plt.ylabel('Non-Alcoholic Beverages - Price')
plt.title(' ')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=2)  # Place legend below the graph area
plt.grid(False)
# Add a vertical line for the event
plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

plt.savefig('non_alcohol_bev.png', bbox_inches='tight')

plt.show()

# %%
# Creating the interaction variables

df = (
    # returns dataframe with dummy columns in place of the columns
    # in the named argument, all other columns untouched
    pd.get_dummies(df, columns=['relative_time'], prefix='INX')
      # Be sure not to include the minuses in the name
      .rename(columns=lambda x: x.replace('-', 'm'))
      # get_dummies has a `drop_first` argument, but if we want to
      # refer to a specific level, we should return all levels and
      # drop out reference column manually
      .drop(columns='INX_m1')
      # Set our individual and time (index) for our data
      .set_index(['i', 't'])
)

df
# Out:
#                              GEO   REF_DATE    Ei      Y  \
# i  t
# 5  1   Newfoundland and Labrador 2021-09-01  13.0  110.2
# 8  1        Prince Edward Island 2021-09-01   NaN  127.2
# 6  1                 Nova Scotia 2021-09-01   NaN  152.9
# 4  1               New Brunswick 2021-09-01   NaN  137.8
# 9  1                      Quebec 2021-09-01   NaN  136.2
# ...                          ...        ...   ...    ...
# 7  27                    Ontario 2023-11-01   NaN  157.0
# 3  27                   Manitoba 2023-11-01   NaN  154.1
# 10 27               Saskatchewan 2023-11-01   NaN  170.0
# 1  27                    Alberta 2023-11-01   NaN  175.9
# 2  27           British Columbia 2023-11-01   NaN  166.9
#
#       Products and product groups  i2  D         GPR  StringencyIndex_Average  \
# i  t
# 5  1      Non-alcoholic beverages   5  0   80.696968                    50.59
# 8  1      Non-alcoholic beverages   8  0   80.696968                    58.33
# ...

# %%
# Defining the exogenous variables

exog = df.columns[df.columns.str.contains('INX')]

# Defining the endogenous variable

endog = 'Y'

# %%
exog
# Out:
# Index(['INX_m12', 'INX_m11', 'INX_m10', 'INX_m9', 'INX_m8', 'INX_m7', 'INX_m6',
#        'INX_m5', 'INX_m4', 'INX_m3', 'INX_m2', 'INX_0', 'INX_1', 'INX_2',
#        'INX_3', 'INX_4', 'INX_5', 'INX_6', 'INX_7', 'INX_8', 'INX_9', 'INX_10',
#        'INX_11', 'INX_12', 'INX_13', 'INX_14'],
#       dtype='object')

# %%
# Estimate the regression

mod = lm.PanelOLS(df[endog], df[exog], entity_effects=True, time_effects=True)
fit = mod.fit(cov_type='clustered', cluster_entity=True)
fit.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                      Y   R-squared:                        0.1972
# Estimator:                   PanelOLS   R-squared (Between):              0.0951
# No. Observations:                 270   R-squared (Within):               0.0419
# Date:                Mon, Feb 19 2024   R-squared (Overall):              0.0948
# Time:                        17:31:01   Log-likelihood                   -592.27
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9651
# Entities:                          10   P-value                           0.0051
# Avg Obs:                       27.000   Distribution:                  F(26,208)
# Min Obs:                       27.000
# Max Obs:                       27.000   F-statistic (robust):          1.462e+15
# ...

# %%
# Creating the regression formula

inxnames = df.columns[df.columns.str.contains('INX')]
formula = '{} ~ {} + EntityEffects + TimeEffects'.format(endog, '+'.join(exog))

mod = lm.PanelOLS.from_formula(formula,df)

# Specify clustering when we fit the model
clfe = mod.fit(cov_type = 'clustered',
    cluster_entity = True)

# Look at regression results
clfe.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                      Y   R-squared:                        0.1972
# Estimator:                   PanelOLS   R-squared (Between):              0.0951
# No. Observations:                 270   R-squared (Within):               0.0419
# Date:                Mon, Feb 19 2024   R-squared (Overall):              0.0948
# Time:                        17:31:02   Log-likelihood                   -592.27
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9651
# Entities:                          10   P-value                           0.0051
# Avg Obs:                       27.000   Distribution:                  F(26,208)
# Min Obs:                       27.000
# Max Obs:                       27.000   F-statistic (robust):          1.462e+15
# ...

# %%
# Get coefficients and CIs
res = pd.concat([clfe.params, clfe.std_errors], axis = 1)
# Scale standard error to 95% CI
res['ci'] = res['std_error']*1.96

# We only want time interactions
res = res.filter(like='INX', axis=0)
# Turn the coefficient names back to numbers
res.index = (
    res.index
        .str.replace('INX_', '')
        .str.replace('m', '-')
        .astype('int')
        .rename('time_to_treat')
)

# And add our reference period back in, and sort automatically
res.reindex(range(res.index.min(), res.index.max()+1)).fillna(0)

res = res.sort_index()

res
# Out:
#                parameter  std_error        ci
# time_to_treat
# -12            -1.277778   2.195039  4.302277
# -11             4.133333   1.903438  3.730739
# -10             5.522222   1.786324  3.501196
# -9              3.388889   1.724674  3.380362
# -8              1.755556   1.954458  3.830738
# -7              0.922222   1.495054  2.930305
# -6             -3.300000   0.808013  1.583705
# -5             -2.733333   1.567089  3.071495
# -4              1.122222   1.993963  3.908168
# -3              2.633333   1.056724  2.071180
# -2              1.877778   1.283122  2.514920
#  0              7.877778   1.064999  2.087399
#  1              8.066667   1.391941  2.728205
#  2              7.111111   1.770434  3.470051
#  3              9.000000   2.152518  4.218935
#  4             11.777778   2.030598  3.979971
#  5              8.833333   1.993981  3.908203
#  6              3.933333   1.765953  3.461268
#  7              7.588889   2.361988  4.629497
# ...

# %% [markdown]
# ## Plotting the Event-Study Figure

# %%
# Setting the size of the figure

plt.figure(figsize=(10, 6))

# Define the time of treatment
treatment_time = 0

# Mask data points before and after the treatment time
before_treatment = res.index < treatment_time
after_treatment = res.index >= treatment_time

# Plot data points before treatment with blue color
ax = res['parameter'][before_treatment].plot(y = 'parameter',
        marker='o', linestyle='-', color='navy', label='Before Treatment')

# Plot data points after treatment with red color
ax = res['parameter'][after_treatment].plot(y = 'parameter',
        marker='s', linestyle='-', color='maroon', label='After Treatment')

# Add a horizontal line at 0
ax.axhline(0, linestyle='dashed', color='gray', linewidth=0.5)
# And a vertical line at the treatment time
ax.axvline(0, linestyle='dashed', color='gray', linewidth=1)

# Get the error values for before and after treatment
error_before = res['ci'][before_treatment]
error_after = res['ci'][after_treatment]

# Add error bars to the lines
plt.errorbar(x=res.index[before_treatment], y=res['parameter'][before_treatment],
             yerr=error_before, fmt='o', linestyle='-', color='navy', label='Pre-trend', capsize=5)
plt.errorbar(x=res.index[after_treatment], y=res['parameter'][after_treatment],
             yerr=error_after, fmt='s', linestyle='-', color='maroon', label='Treatment effects', capsize=5)

# Add labels and title
plt.title('Difference-in-Difference Estimation')
plt.xlabel('Time Period')
plt.ylabel('Non-Alcoholic Beverages - Prices')

# Customize gridlines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Add legend
plt.legend(labels=['Pre-trend', 'Treatment effects'], loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=2)

# Saving figure as a png

plt.savefig('diff-in-diff_sugar_tax.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Showing Control Variables

# %%
# Plot line graph to show Average Weekly Earnings

plt.figure(figsize=(10, 6))
for key, grp in df.groupby('GEO'):
    plt.plot(grp['REF_DATE'], grp['avg_earn'], label=key, marker=markers[marker_index % len(markers)])
    marker_index += 1
plt.xlabel('Date')
plt.ylabel('Average Weekly Earnings')
plt.title(' ')
plt.legend(loc='upper center',
           bbox_to_anchor=(0.5, -0.1),
           fancybox=True,
           shadow=True, ncol=2)  # Place legend below the graph area

# Customize gridlines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a vertical line for the event
plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

plt.savefig('avg_week_earn.png', bbox_inches='tight')

plt.show()

# %%
# Plot line graph to show the Unemployment Rate - Percentage

plt.figure(figsize=(10, 6))
for key, grp in df.groupby('GEO'):
    plt.plot(grp['REF_DATE'], grp['unemp'], label=key, marker=markers[marker_index % len(markers)])
    marker_index += 1
plt.xlabel('Date')
plt.ylabel('Unemployment Rate - Percentage')
plt.title(' ')
plt.legend(loc='upper center',
           bbox_to_anchor=(0.5, -0.1),
           fancybox=True,
           shadow=True, ncol=2)  # Place legend below the graph area

# Customize gridlines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a vertical line for the event

plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

plt.savefig('unemployment_rate.png', bbox_inches='tight')

plt.show()

# %%
# Group the data by Canadian regions
regions = {
    'Atlantic': ['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia', 'New Brunswick'],
    'ON_QC_BC': ['Ontario', 'British Columbia', 'Quebec'],
    'Praries': ['Manitoba', 'Saskatchewan', 'Alberta']
}

marker_index = 1
colors_index = 1

# Creating a separate line plot for each region
for region, provinces in regions.items():
    # Filtering the data for the current region
    region_data = df[df['GEO'].isin(provinces)]

    # Creating a new plot
    plt.figure(figsize=(10, 6))

    # Defining the range for the y-axis
    plt.ylim(0, 17)

    # Iterating over each province in the region and plotting its data
    for province in provinces:
        province_data = region_data[region_data['GEO'] == province]
        plt.plot(province_data['REF_DATE'], province_data['unemp'], label=province, marker=markers[marker_index % len(markers)], color= colors[colors_index % len(colors)])
        marker_index += 1
        colors_index += 1

    # Adding title and labels
    plt.title(' ')
    plt.xlabel('Date')
    plt.ylabel('Unemployment Rate - Percentage')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=2)  # Place legend below the graph area

    # Customize gridlines
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

    # Add a vertical line for the event

    plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

    plt.savefig(f'unemployment_rate_{region}.png', bbox_inches='tight')

    # Show plot
    plt.show()

# %%
# Plotting the Stringency Index (SI)

marker_index = 1
colors_index = 1

# Creating a separate line plot for each region
for region, provinces in regions.items():
    # Filtering the data for the current region
    region_data = df[df['GEO'].isin(provinces)]

    # Creating a new plot
    plt.figure(figsize=(10, 6))

    # Defining the range for the y-axis
    plt.ylim(0, 100)

    # Iterating over each province in the region and plotting its data
    for province in provinces:
        province_data = region_data[region_data['GEO'] == province]
        plt.plot(province_data['REF_DATE'], province_data['StringencyIndex_Average'], label=province, marker=markers[marker_index % len(markers)], color= colors[colors_index % len(colors)])
        marker_index += 1
        colors_index += 1

    # Adding title and labels
    plt.title(' ')
    plt.xlabel('Date')
    plt.ylabel('Unemployment Rate - Percentage')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=2)  # Place legend below the graph area

    # Customize gridlines
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

    # Add a vertical line for the event

    plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

    plt.savefig(f'SI_{region}.png', bbox_inches='tight')

    # Show plot
    plt.show()

# %%
# Plotting the Economic Support Index (SI)

marker_index = 1
colors_index = 1

# Creating a separate line plot for each region
for region, provinces in regions.items():
    # Filtering the data for the current region
    region_data = df[df['GEO'].isin(provinces)]

    # Creating a new plot
    plt.figure(figsize=(10, 6))  # Adjust figure size as needed

    # Defining the range for the y-axis
    plt.ylim(0, 100)

    # Iterating over each province in the region and plotting its data
    for province in provinces:
        province_data = region_data[region_data['GEO'] == province]
        plt.plot(province_data['REF_DATE'], province_data['EconomicSupportIndex'], label=province, marker=markers[marker_index % len(markers)], color= colors[colors_index % len(colors)])
        marker_index += 1
        colors_index += 1

    # Adding title and labels
    plt.title(' ')
    plt.xlabel('Date')
    plt.ylabel('Unemployment Rate - Percentage')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=2)  # Place legend below the graph area
    plt.grid(False)

    # Add a vertical line for the event

    plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

    plt.savefig(f'ESI_{region}.png', bbox_inches='tight')

    # Show plot
    plt.show()

# %%
# Plot line graph to show the other control variables  (interest + WTI_Oil + CADUSD + GPR)

control_vars = {'interest': 'Interest Rate',
                'WTI_Oil': 'WTI Oil Price',
                'CADUSD': 'CAD/USD - Exchange Rate',
                'GPR': 'Geopolitical Risk Index (GPR)'}

for var, lab in control_vars.items():
  plt.figure(figsize=(10, 6))
  plt.plot(df['REF_DATE'], df[var], label=lab, marker='o')

  plt.xlabel('Date')
  plt.ylabel(lab)
  plt.title(' ')

  # Customize gridlines
  plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

  # Add a vertical line for the event

  plt.axvline(x=event_date2, color='gray', linestyle='--', label='Event')

  plt.savefig(f'{var}.png', bbox_inches='tight')

  plt.show()

# %% [markdown]
# ## Running the Static Model

# %% [markdown]
# ### Running the Baseline Static Model

# %%
# Resetting the Index

df.reset_index(drop=False, inplace=True)

# %%
# Running the Baseline Static Model

# Defining the exogenous variables

exog1 = 'D'

# Running the regression

model = sm.ols(
    f"Y ~ {exog1} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe1 = model.fit()

# Look at regression results
clfe1.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     346.6
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          4.45e-182
# Time:                        17:38:46   Log-Likelihood:                -606.70
# No. Observations:                 270   AIC:                             1287.
# Df Residuals:                     233   BIC:                             1421.
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 2

# Defining the exogenous variables

exog2 = 'D + unemp' # + log_avg_earn + interest + WTI_Oil + CADUSD + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog2} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe2 = model.fit()

# Look at regression results
clfe2.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     336.7
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          6.01e-181
# Time:                        17:38:49   Log-Likelihood:                -606.31
# No. Observations:                 270   AIC:                             1289.
# Df Residuals:                     232   BIC:                             1425.
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 3

# Defining the exogenous variables

exog3 = 'D + unemp + log_avg_earn' # + interest + WTI_Oil + CADUSD + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog3} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe3 = model.fit()

# Look at regression results
clfe3.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     326.5
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.11e-179
# Time:                        17:38:50   Log-Likelihood:                -606.31
# No. Observations:                 270   AIC:                             1291.
# Df Residuals:                     231   BIC:                             1431.
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 4

# Defining the exogenous variables

exog4 = 'D + unemp + log_avg_earn + interest' # + WTI_Oil + CADUSD + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog4} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe4 = model.fit()

# Look at regression results
clfe4.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     326.5
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.11e-179
# Time:                        17:38:52   Log-Likelihood:                -606.31
# No. Observations:                 270   AIC:                             1291.
# Df Residuals:                     231   BIC:                             1431.
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 5

# Defining the exogenous variables

exog5 = 'D + unemp + log_avg_earn + interest  + WTI_Oil' #+ CADUSD + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog5} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe5 = model.fit()

# Look at regression results
clfe5.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     326.5
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.11e-179
# Time:                        17:38:53   Log-Likelihood:                -606.31
# No. Observations:                 270   AIC:                             1291.
# Df Residuals:                     231   BIC:                             1431.
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 6

# Defining the exogenous variables

exog6 = 'D + unemp + log_avg_earn + interest  + WTI_Oil + CADUSD'# + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog6} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe6 = model.fit()

# Look at regression results
clfe6.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     326.5
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.11e-179
# Time:                        17:38:55   Log-Likelihood:                -606.31
# No. Observations:                 270   AIC:                             1291.
# Df Residuals:                     231   BIC:                             1431.
# Df Model:                          38
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Static Model - 7

# Defining the exogenous variables

exog7 = 'D + unemp + log_avg_earn + interest  + WTI_Oil + CADUSD + StringencyIndex_Average + EconomicSupportIndex' # + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog7} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe7 = model.fit()

# Look at regression results
clfe7.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     311.0
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.02e-177
# Time:                        17:38:56   Log-Likelihood:                -604.82
# No. Observations:                 270   AIC:                             1292.
# Df Residuals:                     229   BIC:                             1439.
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# Running the Extended Static Model - 8

# Defining the exogenous variables

exog8 = 'D + unemp + log_avg_earn + interest  + WTI_Oil + CADUSD + StringencyIndex_Average + EconomicSupportIndex + GPR'

# Running the regression

model = sm.ols(
    f"Y ~ {exog8} + C(i) + C(t)",
    data=df,
    cluster='i')

clfe8 = model.fit()

# Look at regression results
clfe8.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['cluster']
#   warnings.warn(msg, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     311.0
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          1.02e-177
# Time:                        17:38:57   Log-Likelihood:                -604.82
# No. Observations:                 270   AIC:                             1292.
# Df Residuals:                     229   BIC:                             1439.
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ## Exporting Table as a LaTex File

# %%
# Creating a Dictionary indicating which control variables are included in each model

controls = {'Unemployment': [' ', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark'],
             'Log Earnings': [' ', ' ', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark'],
             'Interest Rate': [' ', ' ', ' ', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark'],
             'WTI Oil': [' ', ' ', ' ', ' ', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark'],
             'CAD/USD': [' ', ' ', ' ', ' ', ' ', '\\checkmark', '\\checkmark', '\\checkmark'],
             'SI': [' ', ' ', ' ', ' ', ' ', ' ', '\\checkmark', '\\checkmark'],
             'ESI': [' ', ' ', ' ', ' ', ' ', ' ', '\\checkmark', '\\checkmark'],
             'GPR': [' ', ' ', ' ', ' ', ' ', ' ', ' ', '\\checkmark'],
             'Time Fixed Effects': ['\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark'],
             'Province Fixed Effects': ['\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark', '\\checkmark']
            }

# Exporting the table of static results to a Latex file

pystout(models=[clfe1, clfe2, clfe3, clfe4, clfe5, clfe6, clfe7, clfe8],
        file='static_model.tex',
        digits= 2, exogvars=['D'], #, 'unemp', 'log_avg_earn', 'StringencyIndex_Average', 'EconomicSupportIndex', 'interest', 'GPR'],
        varlabels={'D': 'Treatment'}, #, 'unemp': 'Unemployment', 'log_avg_earn': 'Log Earnings', 'StringencyIndex_Average': 'SI', 'EconomicSupportIndex': 'ESI', 'interest':'Interest Rate', 'GPR': 'GPR'},
        title='Static Model Results',
        modstat={'nobs': 'N', 'fvalue': 'F-stat'},
        stars={0.1: '*', 0.05: '**', 0.01: '***'},
        addnotes=['t-statistics in parentheses', '* p < 0.1, ** p < 0.05, *** p < 0.01'],
        addrows=controls)
# Out:
# /usr/local/lib/python3.10/dist-packages/pystout/pystout.py:368: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([[str(v) for v in value]],index=[key],columns=df.columns))
# /usr/local/lib/python3.10/dist-packages/pystout/pystout.py:368: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([[str(v) for v in value]],index=[key],columns=df.columns))
# /usr/local/lib/python3.10/dist-packages/pystout/pystout.py:368: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([[str(v) for v in value]],index=[key],columns=df.columns))
# ...

# %% [markdown]
# # Plotting Graph with Static Estimations

# %%
# Store regression results

ols_results = [clfe1, clfe2, clfe3, clfe4, clfe5, clfe6, clfe7, clfe8]

# Extract the coefficient of interest and its confidence intervals from each regression result

coefficients = []
conf_intervals = []

for result in ols_results:
    coefficients.append(result.params['D'])  # Coefficient of interest (index 1)
    conf_intervals.append(result.conf_int().loc['D'])  # Confidence interval for coefficient of interest

# Convert lists to numpy arrays
coefficients = np.array(coefficients)
conf_intervals = np.array(conf_intervals)

# Setting the size of the figure

plt.figure(figsize=(10, 6))

# Plot the coefficients with confidence intervals
plt.errorbar(np.arange(len(coefficients)) + 1, coefficients, yerr=[coefficients - conf_intervals[:, 0], conf_intervals[:, 1] - coefficients], fmt='s', capsize=5, color='maroon')
plt.xlabel('Model Number')
plt.ylabel('Treatment Effect')


# Set the range of the y-axis
plt.ylim(-2, 8)

# Add a horizontal line at y = 0
plt.axhline(0, color='gray', linestyle='dashed', linewidth=1)

# Customize gridlines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Saving figure as a png

plt.savefig('static_model_plot.png', bbox_inches='tight')

plt.show()
